# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# # DATA
# ---

# %%
Data = pd.read_csv('data-1.csv')

# %%
Data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
Data = Data.rename(columns={'fixed acidity':'fixed_acidity','volatile acidity':'volatile_acidity','citric acid':'citric_acid','residual sugar':'residual_sugar','free sulfur dioxide':'free_sulfur_dioxide','total sulfur dioxide':'total_sulfur_dioxide'})

# %% [markdown]
# # DATA DESCRIPTION
# ---

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed_acidity         1600 non-null   float64
#  2   volatile_acidity      1601 non-null   float64
#  3   citric_acid           1600 non-null   float64
#  4   residual_sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free_sulfur_dioxide   1600 non-null   float64
#  7   total_sulfur_dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %% [markdown]
# ### Conclusion
# ---
# There are total of 1601 rows and 13 columns in this Dataframe. It can be seen from the the info above of decreased non null count in some of the columns, i.e. there are some null values in the dataframe in some of the columns and need be filled.
#
# Columns with Null values:
# - fixed acidity
# - citric acid
# - chlorides
# - free sulfur dioxide
# - total sulfur dioxide
# - density
# - pH
# - quality
#
# ---

# %% [markdown]
# # FILLING NULL SPACES IN THE DATAFRAME
# ---

# %%
Data.dropna().head(50)
# Out:
#     ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0    1            7.4             0.700         0.00             1.9
# 1    2            7.8             0.880         0.00             2.6
# 3    4           11.2             0.280         0.56             1.9
# 4    5            7.4             0.700         0.00             1.9
# 5    6            7.4             0.660         0.00             1.8
# 6    7            7.9             0.600         0.06             1.6
# 7    8            7.3             0.650         0.00             1.2
# 8    9            7.8             0.580         0.02             2.0
# 9   10            7.5             0.500         0.36             6.1
# 11  12            7.5             0.500         0.36             6.1
# 12  13            5.6             0.615         0.00             1.6
# 13  14            7.8             0.610         0.29             1.6
# 14  15            8.9             0.620         0.18             3.8
# ...

# %%
Data.describe()
# Out:
#                 ID  fixed_acidity  volatile_acidity  citric_acid  \
# count  1601.000000    1600.000000       1601.000000  1600.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.740039          0.178981     0.194745
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual_sugar    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  \
# count     1601.000000  1598.000000          1600.000000           1600.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047076            10.458487             32.977723
# ...

# %% [markdown]
# ### Deductions
# ---
# For columns **fixed acidity**, **citric acid**, **density**, **pH**, **quality** and **chlorides**, we can replace the null values with the mean of the non null values since the values are between certain range. And for columns **free sulfur dioxide** and **total sulfur dioxide**we can use median since they are not in a particular or declared range. This is to ensure accurate results without any huge deviation from the actual values.
#
# ---

# %% [markdown]
# ### Calculating The Mean, Mode and Median Of The Columns With Null Values
# ---

# %%
mean_FA = Data.fixed_acidity.mean()
mean_CA = Data.citric_acid.mean()
mean_Chl = Data.chlorides.mean()
median_FSD = Data.free_sulfur_dioxide.median()
median_TSD = Data.total_sulfur_dioxide.median()
mean_Dsy = Data.density.mean()
mean_pH = Data.pH.mean()
mean_Q = Data.quality.mean()

# %%
print(f'The mean of Fixed Acidity = {mean_FA}')
print(f'The mean of Citric Acid = {mean_CA}')
print(f'The mean of Chlorides = {mean_Chl}')
print(f'The median of Free Sulfur Dioxide = {median_FSD}')
print(f'The median of Total Sulfur Dioxide = {median_TSD}')
print(f'The mean of Density = {mean_Dsy}')
print(f'The mean of pH = {mean_pH}')
print(f'The mean of Quality = {mean_Q}')
# Out:
# The mean of Fixed Acidity = 8.319875000000001
# The mean of Citric Acid = 0.271175
# The mean of Chlorides = 0.0874874843554443
# The median of Free Sulfur Dioxide = 14.0
# The median of Total Sulfur Dioxide = 38.0
# The mean of Density = 0.9967456437500002
# The mean of pH = 3.3111062500000004
# The mean of Quality = 5.63625

# %% [markdown]
# ### Filling The Null Spaces In The DataFrame with The Above Info
# ---

# %%
Data.fixed_acidity = Data.fixed_acidity.fillna(mean_FA)
Data.citric_acid = Data.citric_acid.fillna(mean_CA)
Data.chlorides = Data.chlorides.fillna(mean_Chl)
Data.free_sulfur_dioxide = Data.free_sulfur_dioxide.fillna(median_FSD)
Data.total_sulfur_dioxide = Data.total_sulfur_dioxide.fillna(median_TSD)
Data.density = Data.density.fillna(mean_Dsy)
Data.pH = Data.pH.fillna(mean_pH)
Data.quality = Data.quality.fillna(mean_Q)

# %% [markdown]
# # DROPPING  DUPLICATES
# ---

# %%
Data.drop_duplicates()
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density        pH  \
# ...

# %% [markdown]
# This was done to ensure that there were no duplicates in the dataframe after filling in the null values.

# %% [markdown]
# # UPDATED DATA DESCRIPTION
# ---

# %%
Data
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density        pH  \
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed_acidity         1601 non-null   float64
#  2   volatile_acidity      1601 non-null   float64
#  3   citric_acid           1601 non-null   float64
#  4   residual_sugar        1601 non-null   float64
#  5   chlorides             1601 non-null   float64
#  6   free_sulfur_dioxide   1601 non-null   float64
#  7   total_sulfur_dioxide  1601 non-null   float64
#  8   density               1601 non-null   float64
#  9   pH                    1601 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1601 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
Data.describe()
# Out:
#                 ID  fixed_acidity  volatile_acidity  citric_acid  \
# count  1601.000000    1601.000000       1601.000000  1601.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.739495          0.178981     0.194684
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual_sugar    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  \
# count     1601.000000  1601.000000          1601.000000           1601.000000
# mean         2.538445     0.087487            15.885696             46.514678
# std          1.409138     0.047032            10.455324             32.968104
# ...

# %% [markdown]
# ### Deduction
# ---
# From the above information provided, we can deduce that are no null values and no duplicates in the dataset.
#
# ---

# %% [markdown]
# # STATISTICAL INFERENCES
# ---

# %% [markdown]
# ## CORRELATION BETWEEN COLUMNS IN THE DATAFRAME
# ---

# %%
Data.corr()
# Out:
#                             ID  fixed_acidity  volatile_acidity  citric_acid  \
# ID                    1.000000      -0.267899         -0.009544    -0.153294
# fixed_acidity        -0.267899       1.000000         -0.255557     0.670856
# volatile_acidity     -0.009544      -0.255557          1.000000    -0.552909
# citric_acid          -0.153294       0.670856         -0.552909     1.000000
# residual_sugar       -0.031589       0.114595          0.001877     0.143517
# chlorides            -0.119131       0.093472          0.060748     0.203981
# free_sulfur_dioxide   0.091296      -0.152961         -0.010643    -0.061175
# total_sulfur_dioxide -0.113531      -0.113172          0.076198     0.036172
# density              -0.368725       0.667693          0.022753     0.364104
# pH                    0.135082      -0.682452          0.235182    -0.542637
# sulphates            -0.124243       0.182291         -0.261364     0.312839
# ...

# %% [markdown]
# ## QUALITY
# ---

# %%
x = Data.quality < mean_Q

# %%
x.value_counts()
# Out:
# False    857
# True     744
# Name: quality, dtype: int64

# %%
plt.pie(x.value_counts(), labels = ['False','True'], autopct = '%.1f%%')
plt.legend(x.value_counts())
plt.title('CORRELATION BETWEEN THE QUALITY VALUES AND ITS MEAN')
# Out:
# Text(0.5, 1.0, 'CORRELATION BETWEEN THE QUALITY VALUES AND ITS MEAN')

# %% [markdown]
# ### Deduction
# This pie chart represents the quality rates of all the samples (1601 entries). This shows the correlation between the quality values of the entries and their mean. The False (Blue) part represents the values greater than the mean value and the True (Orange) represents the values less than the mean value. Therefore we can deduce from the percentages that more quality red wine are produced.
#
# ---

# %% [markdown]
# ## pH
# ---

# %%
sb.histplot(Data.pH)
plt.title('COUNT OF pH VALUES OF ENTRIES')
# Out:
# Text(0.5, 1.0, 'COUNT OF pH VALUES OF ENTRIES')

# %% [markdown]
# ### Deduction
# This shows the count of pH values of the enties or products. This shows that more entries were having their pH around 3.2 to 3.4. Specifically most entries had their entries around 3.3. Research has shown that red wines are generally in the range 3.3 to 3.6. The chart shows the production yielded good quality red wine sine most of the entries are in the 3.2 to 3.6.
#
# ---

# %% [markdown]
# ## ALCOHOL
# ---

# %%
sb.histplot(Data.alcohol)
plt.title('COUNT OF ALCOHOL RATES OF ENTRIES')
# Out:
# Text(0.5, 1.0, 'COUNT OF ALCOHOL RATES OF ENTRIES')

# %% [markdown]
# ### Deduction
# This also shows the alcohol counts of the entries or products. It can be deduced from the above chart that large amount of products find themselves at the range of 9-12 and the a few above and below that range. Then we can say that the alcoholic rate of the wine out 15 is between 9-12.
#
# ---

# %% [markdown]
# ## FIXED ACIDITY
# ---

# %%
y = Data.fixed_acidity < mean_FA
y.value_counts()
# Out:
# True     970
# False    631
# Name: fixed_acidity, dtype: int64

# %%
plt.pie(y.value_counts(), labels = ['True','False'], autopct = '%.1f%%')
plt.legend(y.value_counts())
plt.title('CORRELATION BETWEEN FIXED ACIDITY VALUES AND ITS MEAN')
# Out:
# Text(0.5, 1.0, 'CORRELATION BETWEEN FIXED ACIDITY VALUES AND ITS MEAN')

# %% [markdown]
# ### Deduction
# This pie chart also represents the fixed acidity count of all the samples (1601 entries). This shows the correlation between the individual value of the entries and their mean. The False (Orange) part represents the values greater than the mean value and the True (Blue) represents the values less than the mean value. Therefore we can deduce that more red wine with less acidity are produced, which is good for the health of consumers since more acid can cause damage in the human body.
